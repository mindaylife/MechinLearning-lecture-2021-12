# %% [markdown]
# # 다중회귀 - 보스톤 주택가격

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
df = pd.DataFrame(boston.data, columns=boston.feature_names)
df['PRICE'] = boston.target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %% [markdown]
# - 산점도와 선형회귀선 : seaborn.regplot()

# %%
features = df.columns[1:-1]
print(features)
# Out:
# Index(['ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
sns.regplot(x='CRIM', y="PRICE", data=df)
plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(16,12))
for i, feature in enumerate(features):
    row, col = i//4, i%4
    sns.regplot(x=feature, y="PRICE", data=df, ax=axs[row][col])

# %% [markdown]
# - 어떤 feature가 가격과 상관관계가 높을까?

# %%
from sklearn.linear_model import LinearRegression

# %%
y = boston.target
X = boston.data[:,0:1]      # == X = df["CRIM"].values.reshape(-1,1)
lr = LinearRegression()
lr.fit(X, y)
lr.score(X, y)
# Out:
# 0.15078046904975717

# %%
for i in range(13):
    y = boston.target
    X = boston.data[:,i:i+1]
    lr = LinearRegression()
    lr.fit(X, y)
    lr.score(X, y)
    print(boston.feature_names[i], lr.score(X, y))
# Out:
# CRIM 0.15078046904975717
# ZN 0.12992084489428946
# INDUS 0.2339900304444752
# CHAS 0.03071612970877491
# NOX 0.182603042501699
# RM 0.48352545599133423
# AGE 0.14209474407780442
# DIS 0.062464372121782574
# RAD 0.14563857991232532
# TAX 0.2195259210442193
# PTRATIO 0.257847318009223
# B 0.11119611824636277
# LSTAT 0.5441462975864799

# %%
# 다른방법
y = boston.target
for feature in boston.feature_names:
    X = df[feature].values.reshape(-1,1)
    lr = LinearRegression()
    lr.fit(X, y)
    r2 =lr.score(X, y)
    print(f'{feature}: \t{r2:.4f}')
# Out:
# CRIM: 	0.1508
# ZN: 	0.1299
# INDUS: 	0.2340
# CHAS: 	0.0307
# NOX: 	0.1826
# RM: 	0.4835
# AGE: 	0.1421
# DIS: 	0.0625
# RAD: 	0.1456
# TAX: 	0.2195
# PTRATIO: 	0.2578
# B: 	0.1112
# LSTAT: 	0.5441

# %% [markdown]
# - 다중 선형회귀

# %%
X = boston.data
y = boston.target
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
# 다중 선형회귀에서는 큰 의미 없음
lr.score(X, y)
# Out:
# 0.7406426641094095

# %%
# weight
lr.coef_
# Out:
# array([-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,  2.68673382e+00,
#        -1.77666112e+01,  3.80986521e+00,  6.92224640e-04, -1.47556685e+00,
#         3.06049479e-01, -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#        -5.24758378e-01])

# %%
# bias
lr.intercept_
# Out:
# 36.459488385089855

# %% [markdown]
# - 회귀식
# <pre>
# PRICE = -0.108 * CRIM + 0.046 * ZN + 0.021 * INDUS + 2.69 * CHAS - 0.178 * NOX
# + 3.81 * RM + 0.00069 * AGE - 1.48 * DIS + 0.306 * RAD
# - 0.012 * TAX - 0.953 * PRTATIO + 0.00931 * B - 0.525 * LSTAT + 36.46
# <pre>

# %% [markdown]
# - 테스트 데이터

# %%
boston.data[0]
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#        4.980e+00])

# %%
# 기울기와 절편을 이용한 예측값
np.dot(lr.coef_, boston.data[0]) + lr.intercept_
# Out:
# 30.003843377016814

# %%
# 실제값
boston.target[0]
# Out:
# 24.0

# %%
# 5개 데이터에 대한 예측값 및 실제값
for i in range(5):
    pred = np.dot(lr.coef_, boston.data[i] + lr.intercept_)
    print(f'예측값: {pred:.2f}, 실제값: {boston.target[i]}')
# Out:
# 예측값: -515.44, 실제값: 24.0
# 예측값: -520.42, 실제값: 21.6
# 예측값: -514.88, 실제값: 34.7
# 예측값: -516.84, 실제값: 33.4
# 예측값: -517.50, 실제값: 36.2

# %%
# 데이터가 여러개일 때
lr.predict(boston.data[:5])
# Out:
# array([30.00384338, 25.02556238, 30.56759672, 28.60703649, 27.94352423])

# %%
# 데이터가 한 개일 때
lr.predict(boston.data[0:1]), lr.predict(boston.data[0].reshape(1,-1))
# Out:
# (array([30.00384338]), array([30.00384338]))
